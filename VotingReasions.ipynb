# %%
# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sqlalchemy import create_engine
engine = create_engine('postgresql://stuartlynn@localhost:5432/stuartlynn')
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days
#
# Bad key "axes.spines.right" on line 210 in
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "boxplot.flierprops.linewidth" on line 321 in
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://matplotlib.sf.net/_static/matplotlibrc or from the matplotlib source
# distribution
#
# Bad key "contour.corner_mask" on line 306 in
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# ...

# %%
data = pd.read_csv("voting_reasions_CPS.csv")

# %%
for i in data.columns:
    print i
# Out:
# HRHHID
# HRHHID2
# OCCURNUM
# YYYYMM
# PEAFNOW
# PEEDUCA
# PEMARITL
# PEPARENT
# PERRP
# PESEX
# PESPOUSE
# PRCITFLG
# PRCITSHP
# PRFAMNUM
# PRFAMREL
# PRFAMTYP
# PRMARSTA
# PRPERTYP
# PRTAGE
# PRTFAGE
# PUCHINHH
# PULINENO
# GEREG
# PEDIPGED
# PEHGCOMP
# PECYC
# PEGRPROF
# PEGR6COR
# PEMS123
# PRCHLD
# PRNMCHLD
# PEHSPNON
# GTCBSAST
# GTMETSTA
# GTINDVPC
# GTCBSASZ
# PEAFEVER
# PEAFWHN1
# PEAFWHN2
# PEAFWHN3
# PEAFWHN4
# PEDADTYP
# PELNMOM
# PELNDAD
# PEMOMTYP
# PECOHAB
# PTDTRACE
# PENATVTY
# PEFNTVTY
# PEMNTVTY
# PRDASIAN
# PRDTHSP
# PRINUYER
# GTCSA
# GTCBSA
# PES1
# PES2
# PUSCK4
# PES3
# PES4
# PES5
# PES6
# PES7
# PRS8
# PREDUCA4
# PREDUCA5

# %%
data['le_ages']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-f9bf71de7eef> in <module>()
# ----> 1 data['le_ages']
#
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/stuartlynn/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...
